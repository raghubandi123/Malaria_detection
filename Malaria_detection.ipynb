png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171635_cell_86.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171635_cell_87.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171635_cell_88.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171635_cell_89.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171635_cell_90.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171635_cell_91.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171635_cell_92.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171635_cell_93.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171635_cell_94.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171635_cell_95.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171635_cell_96.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171635_cell_97.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171635_cell_98.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171635_cell_99.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_100.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_101.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_102.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_103.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_104.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_105.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_106.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_107.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_108.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_109.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_110.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_111.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_112.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_113.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_114.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_115.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_116.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_117.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_118.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_75.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_76.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_77.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_78.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_79.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_80.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_81.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_82.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_83.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_84.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_85.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_86.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_87.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_88.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_89.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_90.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_91.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_92.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_93.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_94.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_95.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_96.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_97.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_98.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171739_cell_99.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171809_cell_58.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171809_cell_59.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171809_cell_60.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171809_cell_61.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171809_cell_62.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171809_cell_63.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171809_cell_64.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171809_cell_65.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171809_cell_66.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171809_cell_67.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171809_cell_68.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171809_cell_69.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171809_cell_70.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171809_cell_71.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171809_cell_72.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171809_cell_73.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171809_cell_74.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171809_cell_75.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171809_cell_76.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171809_cell_77.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171809_cell_78.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171809_cell_79.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171809_cell_80.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171809_cell_81.png',
#  'cell_images\\Parasitized\\C116P77ThinF_IMG_20150930_171809_cell_82.png',
#  ...]

# %%
labels=list(map(lambda x: os.path.split(os.path.split(x)[0])[1],filepaths))
labels
# Out:
# ['Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  'Parasitized',
#  ...]

# %%
filepath=pd.Series(filepaths,name='Filepath').astype(str)
labels=pd.Series(labels,name='label')
data=pd.concat([filepath,labels],axis=1)
data=data.sample(frac=1).reset_index(drop=True)
data.head(5)
# Out:
#                                             Filepath       label
# 0  cell_images\Uninfected\C52P13thinF_IMG_2015072...  Uninfected
# 1  cell_images\Uninfected\C202ThinF_IMG_20151015_...  Uninfected
# 2  cell_images\Uninfected\C104P65ThinF_IMG_201509...  Uninfected
# 3  cell_images\Uninfected\C46P7ThinF_IMG_20151130...  Uninfected
# 4  cell_images\Uninfected\C53P14thinF_IMG_2015072...  Uninfected

# %%
counts=data.label.value_counts()
sns.barplot(x=counts.index,y=counts)
plt.xlabel('Type')
plt.xticks()
# Out:
# (array([0, 1]), [Text(0, 0, 'Uninfected'), Text(1, 0, 'Parasitized')])

# %%
train,test=train_test_split(data,test_size=0.25,random_state=42)

# %%
fig,axes= plt.subplots(nrows=5,ncols=3,figsize=(10,8),subplot_kw={'xticks':[],'yticks':[]})
for i,ax in enumerate(axes.flat):
    ax.imshow(plt.imread(data.Filepath[i]))
    ax.set_title(data.label[i])
plt.tight_layout()
plt.show()

# %%
train_datagen=ImageDataGenerator(preprocessing_function=preprocess_input,
                                 validation_split=0.2)
test_datagen=ImageDataGenerator(preprocessing_function=preprocess_input)

# %%
train_gen = train_datagen.flow_from_dataframe(
    dataframe=train,
    x_col='Filepath',
    y_col='label',
    target_size=(100,100),
    class_mode='categorical',
    batch_size=32,
    shuffle=True,
    seed=42
)
valid_gen = train_datagen.flow_from_dataframe(
    dataframe=test,
    x_col='Filepath',
    y_col='label',
    target_size=(100,100),
    class_mode='categorical',
    batch_size=32,
    shuffle=False,
    seed=42
)


test_gen = train_datagen.flow_from_dataframe(
    dataframe=test,
    x_col='Filepath',
    y_col='label',
    target_size=(100,100),
    class_mode='categorical',
    batch_size=32,
    shuffle=False
)
# Out:
# Found 20668 validated image filenames belonging to 2 classes.
# C:\Users\RAGHU\AppData\Roaming\Python\Python39\site-packages\keras\src\legacy\preprocessing\image.py:920: UserWarning: Found 2 invalid image filename(s) in x_col="Filepath". These filename(s) will be ignored.
#   warnings.warn(
# Found 6890 validated image filenames belonging to 2 classes.
# Found 6890 validated image filenames belonging to 2 classes.

# %%
import tensorflow as tf

pretrained_model=tf.keras.applications.MobileNet(
    input_shape=(100,100,3),alpha=1.0,depth_multiplier=1,dropout=0.001,
    include_top=False, weights='imagenet',input_tensor=None,pooling='max',
    classes=1000,classifier_activation='softmax'

)
pretrained_model.trainable=False
# Out:
# C:\Users\RAGHU\AppData\Local\Temp\ipykernel_5208\362221735.py:3: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   pretrained_model=tf.keras.applications.MobileNet(

# %%
inputs=pretrained_model.input
x=Dense(128,activation='relu')(pretrained_model.output)
x=Dense(128,activation='relu')(x)

outputs=Dense(2,activation='softmax')(x)

model=Model(inputs=inputs,outputs=outputs)

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
my_callbacks=[EarlyStopping(monitor='val_accuracy',
                           min_delta=0,
                           patience=2,
                           mode='auto')]

# %%
history =model.fit(
    train_gen,
    validation_data=valid_gen,
epochs=30,
    callbacks=my_callbacks)
# Out:
# Epoch 1/30
# C:\Users\RAGHU\AppData\Roaming\Python\Python39\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 578s 862ms/step - accuracy: 0.8179 - loss: 0.4135 - val_accuracy: 0.8711 - val_loss: 0.3029
# Epoch 2/30
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 359s 555ms/step - accuracy: 0.8737 - loss: 0.2983 - val_accuracy: 0.8695 - val_loss: 0.3030
# Epoch 3/30
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 357s 552ms/step - accuracy: 0.8772 - loss: 0.2791 - val_accuracy: 0.8785 - val_loss: 0.2852
# Epoch 4/30
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 351s 543ms/step - accuracy: 0.8866 - loss: 0.2639 - val_accuracy: 0.8779 - val_loss: 0.2885
# Epoch 5/30
# 646/646 ━━━━━━━━━━━━━━━━━━━━ 360s 556ms/step - accuracy: 0.8911 - loss: 0.2570 - val_accuracy: 0.8756 - val_loss: 0.2948

# %%
model.save("modelmobilenet.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
pd.DataFrame(history.history)[['accuracy','val_accuracy']].plot()
plt.title("Accuracy")
plt.show()

pd.DataFrame(history.history)[['loss','val_loss']].plot()
plt.title('loss')
plt.show()

# %%
results=model.evaluate(test_gen,verbose=0)

print("Test loss: {:.5f}".format(results[0]))
print("Test Accuracy: {:.5f}".format(results[1]*100))
# Out:
# C:\Users\RAGHU\AppData\Roaming\Python\Python39\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Test loss: 0.29480
# Test Accuracy: 87.56168

# %%
pred = model.predict(test_gen)
pred=np.argmax(pred,axis=1)
labels = (train_gen.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred= [labels[k] for k in pred]
# Out:
# 216/216 ━━━━━━━━━━━━━━━━━━━━ 90s 406ms/step

# %%
y_test = list(test.label)
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#  Parasitized       0.93      0.81      0.87      3467
#   Uninfected       0.83      0.94      0.88      3423
#
#     accuracy                           0.88      6890
#    macro avg       0.88      0.88      0.88      6890
# weighted avg       0.88      0.88      0.88      6890

# %%
fig,axes = plt.subplots(nrows=5, ncols=2, figsize=(12,8),subplot_kw={'xticks':[],'yticks':[]})

for i,ax in enumerate(axes.flat):
    ax.imshow(plt.imread(test.Filepath.iloc[i]))
    ax.set_title(f"True:{test.label.iloc[i]}\nPredicted: {pred[i]}")
plt.tight_layout()
plt.show()

# %%
import cv2
import numpy as np
from matplotlib.pyplot import imread
from matplotlib.pyplot import imshow
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.imagenet_utils import decode_predictions
from tensorflow.keras.applications.imagenet_utils import preprocess_input
img_path='C99P60ThinF_IMG_20150918_142334_cell_32.png'
img=cv2.imread(img_path)
img=cv2.resize(img,(100,100))
x=np.expand_dims(img,axis=0)
x=preprocess_input(x)
result=model.predict(x)
print((result*100).astype('int'))
a=np.argmax(result, axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# [[93  6]]

# %%
if(a==1):
    print("Uninfected")
else:
    print("Infected")
# Out:
# Infected
